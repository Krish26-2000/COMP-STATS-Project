# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
raw_data = pd.read_csv('hmda_2007_nationwide_first-lien-owner-occupied-1-4-family-records_labels.csv')
raw_data
# Out:
# C:\Users\Krishna\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (34,36,38,42,44,46,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          as_of_year respondent_id  \
# 0              2007    3027509990
# 1              2007    3027509990
# 2              2007    3027509990
# 3              2007    3028209994
# 4              2007    3027509990
# ...             ...           ...
# 7201361        2007    7101800009
# 7201362        2007    0000008412
# 7201363        2007    0000018836
# 7201364        2007    0000018039
# 7201365        2007    05-0402708
#
#                                          agency_name agency_abbr  agency_code  \
# 0        Department of Housing and Urban Development         HUD            7
# 1        Department of Housing and Urban Development         HUD            7
# ...

# %%
raw_data.columns
# Out:
# Index(['as_of_year', 'respondent_id', 'agency_name', 'agency_abbr',
#        'agency_code', 'loan_type_name', 'loan_type', 'property_type_name',
#        'property_type', 'loan_purpose_name', 'loan_purpose',
#        'owner_occupancy_name', 'owner_occupancy', 'loan_amount_000s',
#        'preapproval_name', 'preapproval', 'action_taken_name', 'action_taken',
#        'msamd_name', 'msamd', 'state_name', 'state_abbr', 'state_code',
#        'county_name', 'county_code', 'census_tract_number',
#        'applicant_ethnicity_name', 'applicant_ethnicity',
#        'co_applicant_ethnicity_name', 'co_applicant_ethnicity',
#        'applicant_race_name_1', 'applicant_race_1', 'applicant_race_name_2',
#        'applicant_race_2', 'applicant_race_name_3', 'applicant_race_3',
#        'applicant_race_name_4', 'applicant_race_4', 'applicant_race_name_5',
#        'applicant_race_5', 'co_applicant_race_name_1', 'co_applicant_race_1',
#        'co_applicant_race_name_2', 'co_applicant_race_2',
# ...

# %%
loan_type_name = raw_data.loan_type_name
loan_type_name_list = raw_data.loan_type_name.to_list()
np.sum(loan_type_name.value_counts())
# Out:
# 7201366

# %%
plt.scatter(loan_type_name,ethnicity)
plt.show()

# %%
ethnicity = raw_data.applicant_ethnicity_name

ethnicity.value_counts()
# Out:
# Not Hispanic or Latino                                                               5688707
# Hispanic or Latino                                                                    770512
# Information not provided by applicant in mail, Internet, or telephone application     736691
# Not applicable                                                                          5456
# Name: applicant_ethnicity_name, dtype: int64

# %%
agency = raw_data.agency_name

agency.value_counts()
# Out:
# Office of the Comptroller of the Currency      2264275
# Department of Housing and Urban Development    1678412
# Office of Thrift Supervision                   1393459
# Federal Reserve System                         1069435
# Federal Deposit Insurance Corporation           512872
# National Credit Union Administration            282913
# Name: agency_name, dtype: int64

# %%
raw_data1 = pd.read_csv('hmda_2015_nationwide_first-lien-owner-occupied-1-4-family-records_labels.csv')
raw_data
# Out:
# C:\Users\Krishna\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (34,36,38,44,46,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          as_of_year respondent_id  \
# 0              2007    3027509990
# 1              2007    3027509990
# 2              2007    3027509990
# 3              2007    3028209994
# 4              2007    3027509990
# ...             ...           ...
# 7201361        2007    7101800009
# 7201362        2007    0000008412
# 7201363        2007    0000018836
# 7201364        2007    0000018039
# 7201365        2007    05-0402708
#
#                                          agency_name agency_abbr  agency_code  \
# 0        Department of Housing and Urban Development         HUD            7
# 1        Department of Housing and Urban Development         HUD            7
# ...

# %%
purchaser = raw_data.purchaser_type_name

purchaser.value_counts()
# Out:
# Loan was not originated or was not sold in calendar year covered by register    2021963
# Fannie Mae (FNMA)                                                               1196674
# Affiliate institution                                                           1096781
# Other type of purchaser                                                          819298
# Freddie Mac (FHLMC)                                                              785450
# Life insurance company, credit union, mortgage bank, or finance company          558665
# Commercial bank, savings bank or savings association                             352396
# Private securitization                                                           185149
# Ginnie Mae (GNMA)                                                                184649
# Farmer Mac (FAMC)                                                                   341
# Name: purchaser_type_name, dtype: int64
